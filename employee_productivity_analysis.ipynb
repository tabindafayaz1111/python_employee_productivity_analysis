# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
import plotly.express as px

# %%
import openpyxl

# %%
df=pd.read_excel(r"C:\Users\fayaz\Downloads\HR_Employee_Performance_Dataset.xlsx")

# %%
df.head()
# Out:
#   Employee ID Employee Name  Department              Job Role Joining Date  \
# 0     EMP0001  Employee 463       Sales       Sales Executive   2018-11-21
# 1     EMP0002   Employee 56       Sales       Account Manager   2018-07-13
# 2     EMP0003  Employee 118  Operations  Supply Chain Analyst   2017-07-09
# 3     EMP0004  Employee 289          HR            HR Manager   2017-10-16
# 4     EMP0005  Employee 128          HR          HR Executive   2023-10-11
#
#    Experience (Years)  Age  Gender  Work Location  Working Hours (Per Week)  \
# 0                 5.1   48  Female  San Francisco                        40
# 1                 5.5   22  Female       New York                        45
# 2                 6.5   59   Other         Austin                        34
# 3                 6.2   37   Other         Austin                        40
# 4                 0.2   24    Male        Chicago                        35
#
#    Performance Rating  Salary ($)  Bonus ($)  Training Hours (Per Year)  \
# 0                   3     4707.36    2923.73                         34
# 1                   2    10320.90    3705.78                         59
# 2                   2    11440.51    1671.09                         80
# 3                   3     7664.84    1570.55                         84
# 4                   5     8464.95    3978.74                         70
#
#    Job Satisfaction Score  Leave Days Taken  Remote Work (%) Promotion Status
# 0                       3                15                3              Yes
# 1                       7                16               92              Yes
# 2                       1                17               40               No
# 3                       2                 9               36              Yes
# 4                       4                 8               64              Yes

# %%
df.tail()
# Out:
#     Employee ID Employee Name Department            Job Role Joining Date  \
# 295     EMP0296  Employee 456  Marketing  Content Strategist   2018-08-16
# 296     EMP0297  Employee 253      Sales     Sales Executive   2015-07-20
# 297     EMP0298  Employee 134  Marketing  Content Strategist   2023-02-13
# 298     EMP0299  Employee 445         IT   Software Engineer   2016-11-02
# 299     EMP0300  Employee 210         IT          IT Support   2023-02-22
#
#      Experience (Years)  Age Gender  Work Location  Working Hours (Per Week)  \
# 295                 5.4   59   Male  San Francisco                        45
# 296                 8.5   43  Other        Seattle                        31
# 297                 0.9   26  Other        Seattle                        43
# 298                 7.2   36  Other  San Francisco                        41
# 299                 0.9   60  Other  San Francisco                        44
#
#      Performance Rating  Salary ($)  Bonus ($)  Training Hours (Per Year)  \
# 295                   3     5656.40    3109.79                         67
# 296                   2     4707.45    2113.55                         72
# 297                   5     4975.94    3018.05                         59
# 298                   5    10869.24    2746.34                         67
# 299                   2     7635.97    1676.32                         50
#
#      Job Satisfaction Score  Leave Days Taken  Remote Work (%)  \
# 295                       2                 4               55
# 296                       2                 3               78
# 297                      10                 4               79
# 298                      10                 2               45
# 299                       8                 1               85
#
#     Promotion Status
# 295               No
# 296              Yes
# 297               No
# 298              Yes
# 299               No

# %%
df.shape
# Out:
# (300, 18)

# %%
df.describe()
# Out:
#               Joining Date  Experience (Years)         Age  \
# count                  300          300.000000  300.000000
# mean   2020-03-13 07:50:24            3.807667   41.790000
# min    2015-01-19 00:00:00           -1.000000   22.000000
# 25%    2017-07-27 00:00:00            1.175000   32.000000
# 50%    2020-06-08 00:00:00            3.550000   41.500000
# 75%    2022-11-02 18:00:00            6.400000   52.000000
# max    2024-12-14 00:00:00            9.000000   60.000000
# std                    NaN            2.958075   11.247857
#
#        Working Hours (Per Week)  Performance Rating    Salary ($)  \
# count                300.000000          300.000000    300.000000
# mean                  39.930000            2.983333   7445.479000
# min                   30.000000            1.000000   3035.290000
# 25%                   35.000000            2.000000   4997.562500
# 50%                   40.000000            3.000000   7362.870000
# 75%                   45.000000            4.000000   9938.020000
# max                   50.000000            5.000000  11991.310000
# std                    5.890736            1.429405   2719.615753
#
#          Bonus ($)  Training Hours (Per Year)  Job Satisfaction Score  \
# count   300.000000                 300.000000              300.000000
# mean   2510.138333                  50.670000                5.590000
# min     504.770000                   5.000000                1.000000
# 25%    1490.407500                  28.750000                3.000000
# 50%    2373.885000                  51.000000                6.000000
# 75%    3558.885000                  74.000000                8.000000
# max    4987.880000                 100.000000               10.000000
# std    1247.869978                  27.101341                2.852312
#
#        Leave Days Taken  Remote Work (%)
# count        300.000000       300.000000
# mean          12.170000        47.683333
# min            0.000000         0.000000
# 25%            5.000000        20.750000
# 50%           12.000000        47.000000
# 75%           19.000000        75.250000
# max           25.000000       100.000000
# std            7.625939        29.506698

# %%
df.dtypes
# Out:
# Employee ID                             str
# Employee Name                           str
# Department                              str
# Job Role                                str
# Joining Date                 datetime64[us]
# Experience (Years)                  float64
# Age                                   int64
# Gender                                  str
# Work Location                           str
# Working Hours (Per Week)              int64
# Performance Rating                    int64
# Salary ($)                          float64
# Bonus ($)                           float64
# Training Hours (Per Year)             int64
# Job Satisfaction Score                int64
# Leave Days Taken                      int64
# Remote Work (%)                       int64
# Promotion Status                        str
# dtype: object

# %%
df.isna().sum()
# Out:
# Employee ID                  0
# Employee Name                0
# Department                   0
# Job Role                     0
# Joining Date                 0
# Experience (Years)           0
# Age                          0
# Gender                       0
# Work Location                0
# Working Hours (Per Week)     0
# Performance Rating           0
# Salary ($)                   0
# Bonus ($)                    0
# Training Hours (Per Year)    0
# Job Satisfaction Score       0
# Leave Days Taken             0
# Remote Work (%)              0
# Promotion Status             0
# dtype: int64

# %%
df['Age_group']=pd.cut(df['Age'],
                       bins=[-float('inf'),26,36,46,55,float('inf')],
                       labels=['0-25', '26-35', '36-45', '46-55', '56+'],
                       right=False)

# %%
df['Remote_Work(%)_Group']=pd.cut(df['Remote Work (%)'],
                       bins=[-float('inf'),26,36,46,55,66,float('inf')],
                       labels=['0-25', '26-35', '36-45', '46-55', '56-65','66+'],
                       right=False)

# %%
df['satisfication_category']=pd.cut(df['Job Satisfaction Score'],
                                   bins=[-float('inf'),3,7,float('inf')],
                                  labels=['low','medium','high'],
                                  right=False)

# %% [markdown]
# ### KPI'S

# %%
EMPLOYEE_COUNT=df['Employee ID'].value_counts().sum()
print(EMPLOYEE_COUNT)
# Out:
# 300

# %%
Average_Experiance=df['Experience (Years)'].mean()
print(Average_Experiance)
# Out:
# 3.8076666666666665

# %%
Avg_performance_rating=df['Performance Rating'].mean()
print(Avg_performance_rating)
# Out:
# 2.9833333333333334

# %%
Average_salary=df['Salary ($)'].mean()
print("$",Average_salary)
# Out:
# $ 7445.478999999999

# %%
total_training_hours=df['Training Hours (Per Year)'].sum()
print(total_training_hours)
# Out:
# 15201

# %% [markdown]
# #### CHARTS

# %% [markdown]
# # productivity analysis

# %%
# Normalize Training Hours
df['Training_norm'] = df['Training Hours (Per Year)'] / df['Training Hours (Per Year)'].max()

# Create Productivity Score
df['Productivity_Score'] = (
    df['Performance Rating'] * 0.5 +
    df['Job Satisfaction Score'] * 0.3 +
    df['Training_norm'] * 0.2
)

df[['Performance Rating','Job Satisfaction Score','Training Hours (Per Year)','Productivity_Score']].head()
# Out:
#    Performance Rating  Job Satisfaction Score  Training Hours (Per Year)  \
# 0                   3                       3                         34
# 1                   2                       7                         59
# 2                   2                       1                         80
# 3                   3                       2                         84
# 4                   5                       4                         70
#
#    Productivity_Score
# 0               2.468
# 1               3.218
# 2               1.460
# 3               2.268
# 4               3.840

# %%
prod_dept = df.groupby('Department')['Productivity_Score'].mean().sort_values(ascending=False)

plt.figure(figsize=(8,5))
prod_dept.plot(kind='bar')
plt.title("Productivity by Department")
plt.ylabel("Average Productivity Score")
plt.bar_label(plt.gca().containers[0],fmt='%.2f')
plt.xticks(rotation=45)
plt.show()

# %%
df.groupby('Gender')['Productivity_Score'].mean()
# Out:
# Gender
# Female    3.353770
# Male      3.311870
# Other     3.157543
# Name: Productivity_Score, dtype: float64

# %%
sb.barplot(data=df, x='Age_group', y='Productivity_Score')
plt.title("Productivity by Age Group")
plt.bar_label(plt.gca().containers[0],fmt='%.2f')
plt.show()

# %%
corr = df.corr(numeric_only=True)

plt.figure(figsize=(8,6))
sb.heatmap(corr[['Productivity_Score']].sort_values(by='Productivity_Score', ascending=False),
           annot=True, cmap='coolwarm')
plt.title("Factors Affecting Productivity")
plt.show()

# %%
sb.scatterplot(data=df, x='Experience (Years)', y='Productivity_Score',hue="Gender")
plt.title("Experience vs Productivity")
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %%
from matplotlib.patches import bbox_artist


sb.scatterplot(data=df, x='Remote Work (%)', y='Productivity_Score',hue='Age')
plt.title("Remote Work vs Productivity")
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %%
sb.scatterplot(data=df, x='Training Hours (Per Year)', y='Productivity_Score')
plt.title("Training vs Productivity")
plt.show()

# %%
top_emp = df.sort_values(by='Productivity_Score', ascending=False).head(10)
low_emp = df.sort_values(by='Productivity_Score').head(10)

top_emp[['Employee ID','Productivity_Score']]
# Out:
#     Employee ID  Productivity_Score
# 133     EMP0134               5.692
# 272     EMP0273               5.662
# 277     EMP0278               5.658
# 146     EMP0147               5.650
# 298     EMP0299               5.634
# 151     EMP0152               5.632
# 297     EMP0298               5.618
# 39      EMP0040               5.608
# 217     EMP0218               5.584
# 292     EMP0293               5.536

# %%
low_emp[['Employee ID','Productivity_Score']]
# Out:
#     Employee ID  Productivity_Score
# 212     EMP0213               0.822
# 116     EMP0117               0.926
# 260     EMP0261               0.932
# 271     EMP0272               1.198
# 288     EMP0289               1.248
# 237     EMP0238               1.364
# 202     EMP0203               1.398
# 53      EMP0054               1.416
# 131     EMP0132               1.426
# 246     EMP0247               1.426

# %%
df['Productivity_Level'] = pd.cut(df['Productivity_Score'],
                                 bins=[0,2,3,5],
                                 labels=['Low','Medium','High'])

sb.countplot(data=df, x='Productivity_Level')
plt.title("Productivity Level Distribution")
plt.bar_label(plt.gca().containers[0])
plt.show()
